# %%
### RUNNABLE SEQUENCE -> USED FOR SEQUENTIAL CONNECTION WHERE OUTPUT OF 1 IS INPUT FOR OTHER

from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
load_dotenv()
from langchain.schema.runnable import RunnableSequence

prompt=PromptTemplate(
    template="Write a joke about {topic}",
    input_variables=['topic']
)

llm = ChatGroq(
    model="deepseek-r1-distill-llama-70b",
    temperature=1.5,
    max_tokens=None,
    reasoning_format="parsed",
    timeout=None,
    max_retries=2,
)

prompt2=PromptTemplate(
    template="Write the explaination of the joke - {text}",
    input_variables=['text']
)

parser=StrOutputParser()

chain =RunnableSequence(prompt,llm,parser,prompt2,llm,parser)
print (chain.invoke({'topic':"AI"}))
# Out:
# **Explanation of the Joke:**
#
# The humor in the joke "Why did the AI go to therapy? It had a recursive anxiety!" lies in a clever play on words. Here's how it unfolds:
#
# 1. **Setup and Structure:** The joke follows the classic "Why did X go to Y?" structure, familiar for its pun- or wordplay-based punchlines. It introduces an unexpected scenario—a sentient AI undergoing therapy—highlighting the mix of technology with human emotion.
#
# 2. **Wordplay with "Recursive":** The punchline revolves around the term "recursive." Typically used in computing to describe a process that calls itself repeatedly, "recursive" here is substituted for "recurrent." This references both actual programming functions and the psychological concept of recurrent thoughts—like recurring anxiety.
#
# 3. **Technical Meets Human:** The joke humorously anthropomorphizes the AI, giving it human emotions. By describing "recursive anxiety," it blends the AI's operational methods (recurrence in neural networks or mental loops) with a human mental health condition, creating a pun that resonates both literally and metaphorically.
#
# 4. **Double Meaning and Twisted humor:** "Recursive anxiety" puns on "recurrent anxiety"—a type of human anxiety. It suggests a self-perpetuating cycle, mirroring both human psychology and a computer's recursive functions. This merging of concepts creates a humorous twist by highlighting similarities between AI's processing and human conditions.
#
# Overall, the joke cleverly blends technical terminology with human emotional experience, finding humor in the AI's need for therapy due to its unique version of anxiety, rooted in its recursive processes.
